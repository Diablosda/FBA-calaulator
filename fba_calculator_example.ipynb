# %% [markdown]
# # FBA费用计算器示例
#
# 本示例展示如何使用FBA费用计算器计算亚马逊FBA配送费用。

# %%
# 导入必要的库
import pandas as pd
import json
from fba_fee_calculator_eu import FBAFeeCalculator_eu
from fba_fee_calculator import FBAFeeCalculator_us

# %% [markdown]
# ## 1. 创建FBA费用计算器实例

# %%
calculator_us = FBAFeeCalculator_us(
    excel_path='逻辑.xlsx',
    fee_table_path='逻辑一维表.csv'
)
calculator_eu = FBAFeeCalculator_eu(
    excel_path='欧洲逻辑.xlsx',
    fee_table_path='英德逻辑一维表.csv'
)
# Out:
# 尺寸分段数据从 e:\Python Project\核算数据\FBA费核算\逻辑.xlsx 加载成功，形状: (19, 6)
# 费用表数据加载完成
# 费用表数据形状: (243, 5)
#
# 价格区间: ['<10', '[10,50]', '>50']
#
# 商品尺寸: ['小号标准尺寸', '大号标准尺寸', '小号大件', '大号大件', '超大件((0,50]磅)', '超大件((50,70]磅)', '超大件((70,150]磅)', '超大件(>150磅)']
# 尺寸分段数据从 e:\Python Project\核算数据\FBA费核算\欧洲逻辑.xlsx 加载成功，形状: (13, 6)
# 费用表数据加载完成
# 费用表数据形状: (168, 5)
#
# 商品尺寸: ['轻型信封', '标准信封', '大号信封', '超大号信封', '小包裹', '标准包裹', '小号大件', '轻型标准大件', '重型标准大件', '大号标准大件', '特大号大件', '超重型大件', '特殊大件']

# %%
# 定义要计算的时期
periods = [
    "2025年01月15日至2025年10月14日",
    "2025年10月15日至2026年01月14日",
    "自2026年01月15日起"
]

# 处理产品数据文件
result_df_us = calculator_us.process_file(
    file_path='10月fba.xlsx',
    periods=periods
)

# %%
# 定义要计算的时期
periods = [
    "2025年1月15日至2025年10月14日",
    "2025年10月15日至2026年1月14日",
]

# 处理产品数据文件
result_df_eu = calculator_eu.process_file(
    file_path='eu的fba.xlsx',
    periods=periods
)
# Out:
# 检查重量 3174.7775999999994g 是否在范围 <=150 内
# 小于等于判断: 3174.7775999999994 <= 150.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=400 内
# 小于等于判断: 3174.7775999999994 <= 400.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=900 内
# 小于等于判断: 3174.7775999999994 <= 900.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=1400 内
# 小于等于判断: 3174.7775999999994 <= 1400.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=1900 内
# 小于等于判断: 3174.7775999999994 <= 1900.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=2900 内
# 小于等于判断: 3174.7775999999994 <= 2900.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=3900 内
# 小于等于判断: 3174.7775999999994 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3174.7775999999994磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.67
# 固定费用: $5.67
# 检查重量 3174.7775999999994g 是否在范围 <=150 内
# 小于等于判断: 3174.7775999999994 <= 150.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=400 内
# 小于等于判断: 3174.7775999999994 <= 400.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=900 内
# 小于等于判断: 3174.7775999999994 <= 900.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=1400 内
# 小于等于判断: 3174.7775999999994 <= 1400.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=1900 内
# 小于等于判断: 3174.7775999999994 <= 1900.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=2900 内
# 小于等于判断: 3174.7775999999994 <= 2900.0 = False
# 检查重量 3174.7775999999994g 是否在范围 <=3900 内
# 小于等于判断: 3174.7775999999994 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3174.7775999999994磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.94
# 固定费用: $5.94
# 检查重量 2573.232872g 是否在范围 <=760 内
# 小于等于判断: 2573.232872 <= 760.0 = False
# 检查重量 2573.232872g 是否在范围 >760 内
# 大于判断: 2573.232872 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 小号大件
# 使用的重量: 2573.232872磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.79+((发货重量-760)/1000)*0.48
# 计算公式: 4.79+((2573.232872-760)/1000)*0.48
# 计算结果: $5.66
# 检查重量 2573.232872g 是否在范围 <=760 内
# 小于等于判断: 2573.232872 <= 760.0 = False
# 检查重量 2573.232872g 是否在范围 >760 内
# 大于判断: 2573.232872 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 小号大件
# 使用的重量: 2573.232872磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.79+((发货重量-760)/1000)*0.48
# 计算公式: 4.79+((2573.232872-760)/1000)*0.48
# 计算结果: $5.66
# 检查重量 4064.0599999999995g 是否在范围 <=150 内
# 小于等于判断: 4064.0599999999995 <= 150.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=400 内
# 小于等于判断: 4064.0599999999995 <= 400.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=900 内
# 小于等于判断: 4064.0599999999995 <= 900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=1400 内
# 小于等于判断: 4064.0599999999995 <= 1400.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=1900 内
# 小于等于判断: 4064.0599999999995 <= 1900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=2900 内
# 小于等于判断: 4064.0599999999995 <= 2900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=3900 内
# 小于等于判断: 4064.0599999999995 <= 3900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=5900 内
# 小于等于判断: 4064.0599999999995 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 4064.0599999999995磅 (匹配范围: <=5900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.95
# 固定费用: $5.95
# 检查重量 4064.0599999999995g 是否在范围 <=150 内
# 小于等于判断: 4064.0599999999995 <= 150.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=400 内
# 小于等于判断: 4064.0599999999995 <= 400.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=900 内
# 小于等于判断: 4064.0599999999995 <= 900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=1400 内
# 小于等于判断: 4064.0599999999995 <= 1400.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=1900 内
# 小于等于判断: 4064.0599999999995 <= 1900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=2900 内
# 小于等于判断: 4064.0599999999995 <= 2900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=3900 内
# 小于等于判断: 4064.0599999999995 <= 3900.0 = False
# 检查重量 4064.0599999999995g 是否在范围 <=5900 内
# 小于等于判断: 4064.0599999999995 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 4064.0599999999995磅 (匹配范围: <=5900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 6.23
# 固定费用: $6.23
# 检查重量 6689.083240000002g 是否在范围 <=760 内
# 小于等于判断: 6689.083240000002 <= 760.0 = False
# 检查重量 6689.083240000002g 是否在范围 >760 内
# 大于判断: 6689.083240000002 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 6689.083240000002磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((6689.083240000002-760)/1000)*0.29
# 计算结果: $6.63
# 检查重量 6689.083240000002g 是否在范围 <=760 内
# 小于等于判断: 6689.083240000002 <= 760.0 = False
# 检查重量 6689.083240000002g 是否在范围 >760 内
# 大于判断: 6689.083240000002 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 6689.083240000002磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((6689.083240000002-760)/1000)*0.29
# 计算结果: $6.63
# 检查重量 942.3840660000001g 是否在范围 <=150 内
# 小于等于判断: 942.3840660000001 <= 150.0 = False
# 检查重量 942.3840660000001g 是否在范围 <=400 内
# 小于等于判断: 942.3840660000001 <= 400.0 = False
# 检查重量 942.3840660000001g 是否在范围 <=900 内
# 小于等于判断: 942.3840660000001 <= 900.0 = False
# 检查重量 942.3840660000001g 是否在范围 <=1400 内
# 小于等于判断: 942.3840660000001 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 942.3840660000001磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.29
# 固定费用: $4.29
# 检查重量 942.3840660000001g 是否在范围 <=150 内
# 小于等于判断: 942.3840660000001 <= 150.0 = False
# 检查重量 942.3840660000001g 是否在范围 <=400 内
# 小于等于判断: 942.3840660000001 <= 400.0 = False
# 检查重量 942.3840660000001g 是否在范围 <=900 内
# 小于等于判断: 942.3840660000001 <= 900.0 = False
# 检查重量 942.3840660000001g 是否在范围 <=1400 内
# 小于等于判断: 942.3840660000001 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 942.3840660000001磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.49
# 固定费用: $4.49
# 检查重量 1238.9111487999999g 是否在范围 <=150 内
# 小于等于判断: 1238.9111487999999 <= 150.0 = False
# 检查重量 1238.9111487999999g 是否在范围 <=400 内
# 小于等于判断: 1238.9111487999999 <= 400.0 = False
# 检查重量 1238.9111487999999g 是否在范围 <=900 内
# 小于等于判断: 1238.9111487999999 <= 900.0 = False
# 检查重量 1238.9111487999999g 是否在范围 <=1400 内
# 小于等于判断: 1238.9111487999999 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1238.9111487999999磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.54
# 固定费用: $4.54
# 检查重量 1238.9111487999999g 是否在范围 <=150 内
# 小于等于判断: 1238.9111487999999 <= 150.0 = False
# 检查重量 1238.9111487999999g 是否在范围 <=400 内
# 小于等于判断: 1238.9111487999999 <= 400.0 = False
# 检查重量 1238.9111487999999g 是否在范围 <=900 内
# 小于等于判断: 1238.9111487999999 <= 900.0 = False
# 检查重量 1238.9111487999999g 是否在范围 <=1400 内
# 小于等于判断: 1238.9111487999999 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1238.9111487999999磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.75
# 固定费用: $4.75
# 检查重量 8369.6348736g 是否在范围 <=760 内
# 小于等于判断: 8369.6348736 <= 760.0 = False
# 检查重量 8369.6348736g 是否在范围 >760 内
# 大于判断: 8369.6348736 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8369.6348736磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((8369.6348736-760)/1000)*0.29
# 计算结果: $7.12
# 检查重量 8369.6348736g 是否在范围 <=760 内
# 小于等于判断: 8369.6348736 <= 760.0 = False
# 检查重量 8369.6348736g 是否在范围 >760 内
# 大于判断: 8369.6348736 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8369.6348736磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((8369.6348736-760)/1000)*0.29
# 计算结果: $7.12
# 检查重量 4491.02g 是否在范围 <=760 内
# 小于等于判断: 4491.02 <= 760.0 = False
# 检查重量 4491.02g 是否在范围 >760 内
# 大于判断: 4491.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 4491.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((4491.02-760)/1000)*0.29
# 计算结果: $5.99
# 检查重量 4491.02g 是否在范围 <=760 内
# 小于等于判断: 4491.02 <= 760.0 = False
# 检查重量 4491.02g 是否在范围 >760 内
# 大于判断: 4491.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 4491.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((4491.02-760)/1000)*0.29
# 计算结果: $5.99
# 检查重量 4110.0g 是否在范围 <=760 内
# 小于等于判断: 4110.0 <= 760.0 = False
# 检查重量 4110.0g 是否在范围 >760 内
# 大于判断: 4110.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 4110.0磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((4110.0-760)/1000)*0.29
# 计算结果: $5.88
# 检查重量 4110.0g 是否在范围 <=760 内
# 小于等于判断: 4110.0 <= 760.0 = False
# 检查重量 4110.0g 是否在范围 >760 内
# 大于判断: 4110.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 4110.0磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((4110.0-760)/1000)*0.29
# 计算结果: $5.88
# 检查重量 9640.9566g 是否在范围 <=760 内
# 小于等于判断: 9640.9566 <= 760.0 = False
# 检查重量 9640.9566g 是否在范围 >760 内
# 大于判断: 9640.9566 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9640.9566磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((9640.9566-760)/1000)*0.24
# 计算结果: $6.8
# 检查重量 9640.9566g 是否在范围 <=760 内
# 小于等于判断: 9640.9566 <= 760.0 = False
# 检查重量 9640.9566g 是否在范围 >760 内
# 大于判断: 9640.9566 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9640.9566磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((9640.9566-760)/1000)*0.24
# 计算结果: $6.8
# 检查重量 1075.7471759999999g 是否在范围 <=150 内
# 小于等于判断: 1075.7471759999999 <= 150.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=400 内
# 小于等于判断: 1075.7471759999999 <= 400.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=900 内
# 小于等于判断: 1075.7471759999999 <= 900.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=1400 内
# 小于等于判断: 1075.7471759999999 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 1075.7471759999999磅 (匹配范围: <=1400g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.05
# 固定费用: $3.05
# 检查重量 1075.7471759999999g 是否在范围 <=150 内
# 小于等于判断: 1075.7471759999999 <= 150.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=400 内
# 小于等于判断: 1075.7471759999999 <= 400.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=900 内
# 小于等于判断: 1075.7471759999999 <= 900.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=1400 内
# 小于等于判断: 1075.7471759999999 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 1075.7471759999999磅 (匹配范围: <=1400g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.14
# 固定费用: $3.14
# 检查重量 179.99g 是否在范围 <=960 内
# 小于等于判断: 179.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 179.99磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.94
# 固定费用: $2.94
# 检查重量 179.99g 是否在范围 <=960 内
# 小于等于判断: 179.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 179.99磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3
# 固定费用: $3.0
# 检查重量 803.3440000000002g 是否在范围 <=150 内
# 小于等于判断: 803.3440000000002 <= 150.0 = False
# 检查重量 803.3440000000002g 是否在范围 <=400 内
# 小于等于判断: 803.3440000000002 <= 400.0 = False
# 检查重量 803.3440000000002g 是否在范围 <=900 内
# 小于等于判断: 803.3440000000002 <= 900.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 803.3440000000002磅 (匹配范围: <=900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 803.3440000000002g 是否在范围 <=150 内
# 小于等于判断: 803.3440000000002 <= 150.0 = False
# 检查重量 803.3440000000002g 是否在范围 <=400 内
# 小于等于判断: 803.3440000000002 <= 400.0 = False
# 检查重量 803.3440000000002g 是否在范围 <=900 内
# 小于等于判断: 803.3440000000002 <= 900.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 803.3440000000002磅 (匹配范围: <=900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.13
# 固定费用: $3.13
# 检查重量 130.0g 是否在范围 <=960 内
# 小于等于判断: 130.0 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 130.0磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.72
# 固定费用: $2.72
# 检查重量 130.0g 是否在范围 <=960 内
# 小于等于判断: 130.0 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 130.0磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.77
# 固定费用: $2.77
# 检查重量 170.01g 是否在范围 <=150 内
# 小于等于判断: 170.01 <= 150.0 = False
# 检查重量 170.01g 是否在范围 <=400 内
# 小于等于判断: 170.01 <= 400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 170.01磅 (匹配范围: <=400g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3
# 固定费用: $3.0
# 检查重量 170.01g 是否在范围 <=150 内
# 小于等于判断: 170.01 <= 150.0 = False
# 检查重量 170.01g 是否在范围 <=400 内
# 小于等于判断: 170.01 <= 400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 170.01磅 (匹配范围: <=400g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.09
# 固定费用: $3.09
# 检查重量 939.98g 是否在范围 <=150 内
# 小于等于判断: 939.98 <= 150.0 = False
# 检查重量 939.98g 是否在范围 <=400 内
# 小于等于判断: 939.98 <= 400.0 = False
# 检查重量 939.98g 是否在范围 <=900 内
# 小于等于判断: 939.98 <= 900.0 = False
# 检查重量 939.98g 是否在范围 <=1400 内
# 小于等于判断: 939.98 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 939.98磅 (匹配范围: <=1400g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.05
# 固定费用: $3.05
# 检查重量 939.98g 是否在范围 <=150 内
# 小于等于判断: 939.98 <= 150.0 = False
# 检查重量 939.98g 是否在范围 <=400 内
# 小于等于判断: 939.98 <= 400.0 = False
# 检查重量 939.98g 是否在范围 <=900 内
# 小于等于判断: 939.98 <= 900.0 = False
# 检查重量 939.98g 是否在范围 <=1400 内
# 小于等于判断: 939.98 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 939.98磅 (匹配范围: <=1400g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.14
# 固定费用: $3.14
# 检查重量 20.0g 是否在范围 <=20 内
# 小于等于判断: 20.0 <= 20.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型信封
# 使用的重量: 20.0磅 (匹配范围: <=20g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 1.83
# 固定费用: $1.83
# 检查重量 20.0g 是否在范围 <=20 内
# 小于等于判断: 20.0 <= 20.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型信封
# 使用的重量: 20.0磅 (匹配范围: <=20g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 1.83
# 固定费用: $1.83
# 检查重量 5258.9232827999995g 是否在范围 <=760 内
# 小于等于判断: 5258.9232827999995 <= 760.0 = False
# 检查重量 5258.9232827999995g 是否在范围 >760 内
# 大于判断: 5258.9232827999995 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 5258.9232827999995磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((5258.9232827999995-760)/1000)*0.24
# 计算结果: $5.75
# 检查重量 5258.9232827999995g 是否在范围 <=760 内
# 小于等于判断: 5258.9232827999995 <= 760.0 = False
# 检查重量 5258.9232827999995g 是否在范围 >760 内
# 大于判断: 5258.9232827999995 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 5258.9232827999995磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((5258.9232827999995-760)/1000)*0.24
# 计算结果: $5.75
# 检查重量 89.99g 是否在范围 <=960 内
# 小于等于判断: 89.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 89.99磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.72
# 固定费用: $2.72
# 检查重量 89.99g 是否在范围 <=960 内
# 小于等于判断: 89.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 89.99磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.77
# 固定费用: $2.77
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.94
# 固定费用: $2.94
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3
# 固定费用: $3.0
# 检查重量 4209.92g 是否在范围 <=150 内
# 小于等于判断: 4209.92 <= 150.0 = False
# 检查重量 4209.92g 是否在范围 <=400 内
# 小于等于判断: 4209.92 <= 400.0 = False
# 检查重量 4209.92g 是否在范围 <=900 内
# 小于等于判断: 4209.92 <= 900.0 = False
# 检查重量 4209.92g 是否在范围 <=1400 内
# 小于等于判断: 4209.92 <= 1400.0 = False
# 检查重量 4209.92g 是否在范围 <=1900 内
# 小于等于判断: 4209.92 <= 1900.0 = False
# 检查重量 4209.92g 是否在范围 <=2900 内
# 小于等于判断: 4209.92 <= 2900.0 = False
# 检查重量 4209.92g 是否在范围 <=3900 内
# 小于等于判断: 4209.92 <= 3900.0 = False
# 检查重量 4209.92g 是否在范围 <=5900 内
# 小于等于判断: 4209.92 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 4209.92磅 (匹配范围: <=5900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.19
# 固定费用: $5.19
# 检查重量 4209.92g 是否在范围 <=150 内
# 小于等于判断: 4209.92 <= 150.0 = False
# 检查重量 4209.92g 是否在范围 <=400 内
# 小于等于判断: 4209.92 <= 400.0 = False
# 检查重量 4209.92g 是否在范围 <=900 内
# 小于等于判断: 4209.92 <= 900.0 = False
# 检查重量 4209.92g 是否在范围 <=1400 内
# 小于等于判断: 4209.92 <= 1400.0 = False
# 检查重量 4209.92g 是否在范围 <=1900 内
# 小于等于判断: 4209.92 <= 1900.0 = False
# 检查重量 4209.92g 是否在范围 <=2900 内
# 小于等于判断: 4209.92 <= 2900.0 = False
# 检查重量 4209.92g 是否在范围 <=3900 内
# 小于等于判断: 4209.92 <= 3900.0 = False
# 检查重量 4209.92g 是否在范围 <=5900 内
# 小于等于判断: 4209.92 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 4209.92磅 (匹配范围: <=5900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.34
# 固定费用: $5.34
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.94
# 固定费用: $2.94
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3
# 固定费用: $3.0
# 检查重量 2720.01g 是否在范围 <=760 内
# 小于等于判断: 2720.01 <= 760.0 = False
# 检查重量 2720.01g 是否在范围 >760 内
# 大于判断: 2720.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 2720.01磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((2720.01-760)/1000)*0.24
# 计算结果: $5.14
# 检查重量 2720.01g 是否在范围 <=760 内
# 小于等于判断: 2720.01 <= 760.0 = False
# 检查重量 2720.01g 是否在范围 >760 内
# 大于判断: 2720.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 2720.01磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((2720.01-760)/1000)*0.24
# 计算结果: $5.14
# 检查重量 11260.02g 是否在范围 <=760 内
# 小于等于判断: 11260.02 <= 760.0 = False
# 检查重量 11260.02g 是否在范围 >760 内
# 大于判断: 11260.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 11260.02磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((11260.02-760)/1000)*0.24
# 计算结果: $7.19
# 检查重量 11260.02g 是否在范围 <=760 内
# 小于等于判断: 11260.02 <= 760.0 = False
# 检查重量 11260.02g 是否在范围 >760 内
# 大于判断: 11260.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 11260.02磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((11260.02-760)/1000)*0.24
# 计算结果: $7.19
# 检查重量 8323.01g 是否在范围 <=760 内
# 小于等于判断: 8323.01 <= 760.0 = False
# 检查重量 8323.01g 是否在范围 >760 内
# 大于判断: 8323.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8323.01磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((8323.01-760)/1000)*0.24
# 计算结果: $6.49
# 检查重量 8323.01g 是否在范围 <=760 内
# 小于等于判断: 8323.01 <= 760.0 = False
# 检查重量 8323.01g 是否在范围 >760 内
# 大于判断: 8323.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8323.01磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((8323.01-760)/1000)*0.24
# 计算结果: $6.49
# 检查重量 100.02g 是否在范围 <=960 内
# 小于等于判断: 100.02 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 100.02磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.72
# 固定费用: $2.72
# 检查重量 100.02g 是否在范围 <=960 内
# 小于等于判断: 100.02 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 100.02磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.77
# 固定费用: $2.77
# 检查重量 89.99g 是否在范围 <=960 内
# 小于等于判断: 89.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 89.99磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.94
# 固定费用: $2.94
# 检查重量 89.99g 是否在范围 <=960 内
# 小于等于判断: 89.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 89.99磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3
# 固定费用: $3.0
# 检查重量 13877.102073599997g 是否在范围 <=760 内
# 小于等于判断: 13877.102073599997 <= 760.0 = False
# 检查重量 13877.102073599997g 是否在范围 >760 内
# 大于判断: 13877.102073599997 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 13877.102073599997磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((13877.102073599997-760)/1000)*0.24
# 计算结果: $7.82
# 检查重量 13877.102073599997g 是否在范围 <=760 内
# 小于等于判断: 13877.102073599997 <= 760.0 = False
# 检查重量 13877.102073599997g 是否在范围 >760 内
# 大于判断: 13877.102073599997 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 13877.102073599997磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((13877.102073599997-760)/1000)*0.24
# 计算结果: $7.82
# 检查重量 14820.0g 是否在范围 <=760 内
# 小于等于判断: 14820.0 <= 760.0 = False
# 检查重量 14820.0g 是否在范围 >760 内
# 大于判断: 14820.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 14820.0磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((14820.0-760)/1000)*0.24
# 计算结果: $8.04
# 检查重量 14820.0g 是否在范围 <=760 内
# 小于等于判断: 14820.0 <= 760.0 = False
# 检查重量 14820.0g 是否在范围 >760 内
# 大于判断: 14820.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 14820.0磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((14820.0-760)/1000)*0.24
# 计算结果: $8.04
# 检查重量 479.2218g 是否在范围 <=150 内
# 小于等于判断: 479.2218 <= 150.0 = False
# 检查重量 479.2218g 是否在范围 <=400 内
# 小于等于判断: 479.2218 <= 400.0 = False
# 检查重量 479.2218g 是否在范围 <=900 内
# 小于等于判断: 479.2218 <= 900.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 479.2218磅 (匹配范围: <=900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 479.2218g 是否在范围 <=150 内
# 小于等于判断: 479.2218 <= 150.0 = False
# 检查重量 479.2218g 是否在范围 <=400 内
# 小于等于判断: 479.2218 <= 400.0 = False
# 检查重量 479.2218g 是否在范围 <=900 内
# 小于等于判断: 479.2218 <= 900.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 479.2218磅 (匹配范围: <=900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.13
# 固定费用: $3.13
# 检查重量 3806.5284g 是否在范围 <=150 内
# 小于等于判断: 3806.5284 <= 150.0 = False
# 检查重量 3806.5284g 是否在范围 <=400 内
# 小于等于判断: 3806.5284 <= 400.0 = False
# 检查重量 3806.5284g 是否在范围 <=900 内
# 小于等于判断: 3806.5284 <= 900.0 = False
# 检查重量 3806.5284g 是否在范围 <=1400 内
# 小于等于判断: 3806.5284 <= 1400.0 = False
# 检查重量 3806.5284g 是否在范围 <=1900 内
# 小于等于判断: 3806.5284 <= 1900.0 = False
# 检查重量 3806.5284g 是否在范围 <=2900 内
# 小于等于判断: 3806.5284 <= 2900.0 = False
# 检查重量 3806.5284g 是否在范围 <=3900 内
# 小于等于判断: 3806.5284 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3806.5284磅 (匹配范围: <=3900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.16
# 固定费用: $5.16
# 检查重量 3806.5284g 是否在范围 <=150 内
# 小于等于判断: 3806.5284 <= 150.0 = False
# 检查重量 3806.5284g 是否在范围 <=400 内
# 小于等于判断: 3806.5284 <= 400.0 = False
# 检查重量 3806.5284g 是否在范围 <=900 内
# 小于等于判断: 3806.5284 <= 900.0 = False
# 检查重量 3806.5284g 是否在范围 <=1400 内
# 小于等于判断: 3806.5284 <= 1400.0 = False
# 检查重量 3806.5284g 是否在范围 <=1900 内
# 小于等于判断: 3806.5284 <= 1900.0 = False
# 检查重量 3806.5284g 是否在范围 <=2900 内
# 小于等于判断: 3806.5284 <= 2900.0 = False
# 检查重量 3806.5284g 是否在范围 <=3900 内
# 小于等于判断: 3806.5284 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3806.5284磅 (匹配范围: <=3900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.32
# 固定费用: $5.32
# 检查重量 9569.9007956g 是否在范围 <=760 内
# 小于等于判断: 9569.9007956 <= 760.0 = False
# 检查重量 9569.9007956g 是否在范围 >760 内
# 大于判断: 9569.9007956 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9569.9007956磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((9569.9007956-760)/1000)*0.24
# 计算结果: $6.78
# 检查重量 9569.9007956g 是否在范围 <=760 内
# 小于等于判断: 9569.9007956 <= 760.0 = False
# 检查重量 9569.9007956g 是否在范围 >760 内
# 大于判断: 9569.9007956 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9569.9007956磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((9569.9007956-760)/1000)*0.24
# 计算结果: $6.78
# 检查重量 4760.0g 是否在范围 <=760 内
# 小于等于判断: 4760.0 <= 760.0 = False
# 检查重量 4760.0g 是否在范围 >760 内
# 大于判断: 4760.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 4760.0磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((4760.0-760)/1000)*0.24
# 计算结果: $5.63
# 检查重量 4760.0g 是否在范围 <=760 内
# 小于等于判断: 4760.0 <= 760.0 = False
# 检查重量 4760.0g 是否在范围 >760 内
# 大于判断: 4760.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 4760.0磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((4760.0-760)/1000)*0.24
# 计算结果: $5.63
# 检查重量 3900.99g 是否在范围 <=760 内
# 小于等于判断: 3900.99 <= 760.0 = False
# 检查重量 3900.99g 是否在范围 >760 内
# 大于判断: 3900.99 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 3900.99磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((3900.99-760)/1000)*0.24
# 计算结果: $5.42
# 检查重量 3900.99g 是否在范围 <=760 内
# 小于等于判断: 3900.99 <= 760.0 = False
# 检查重量 3900.99g 是否在范围 >760 内
# 大于判断: 3900.99 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 3900.99磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((3900.99-760)/1000)*0.24
# 计算结果: $5.42
# 检查重量 40.01g 是否在范围 <=960 内
# 小于等于判断: 40.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 40.01磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.42
# 固定费用: $3.42
# 检查重量 40.01g 是否在范围 <=960 内
# 小于等于判断: 40.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 40.01磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.42
# 固定费用: $3.42
# 检查重量 1999.98g 是否在范围 <=150 内
# 小于等于判断: 1999.98 <= 150.0 = False
# 检查重量 1999.98g 是否在范围 <=400 内
# 小于等于判断: 1999.98 <= 400.0 = False
# 检查重量 1999.98g 是否在范围 <=900 内
# 小于等于判断: 1999.98 <= 900.0 = False
# 检查重量 1999.98g 是否在范围 <=1400 内
# 小于等于判断: 1999.98 <= 1400.0 = False
# 检查重量 1999.98g 是否在范围 <=1900 内
# 小于等于判断: 1999.98 <= 1900.0 = False
# 检查重量 1999.98g 是否在范围 <=2900 内
# 小于等于判断: 1999.98 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1999.98磅 (匹配范围: <=2900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.73
# 固定费用: $4.73
# 检查重量 1999.98g 是否在范围 <=150 内
# 小于等于判断: 1999.98 <= 150.0 = False
# 检查重量 1999.98g 是否在范围 <=400 内
# 小于等于判断: 1999.98 <= 400.0 = False
# 检查重量 1999.98g 是否在范围 <=900 内
# 小于等于判断: 1999.98 <= 900.0 = False
# 检查重量 1999.98g 是否在范围 <=1400 内
# 小于等于判断: 1999.98 <= 1400.0 = False
# 检查重量 1999.98g 是否在范围 <=1900 内
# 小于等于判断: 1999.98 <= 1900.0 = False
# 检查重量 1999.98g 是否在范围 <=2900 内
# 小于等于判断: 1999.98 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1999.98磅 (匹配范围: <=2900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.87
# 固定费用: $4.87
# 检查重量 468.832g 是否在范围 <=150 内
# 小于等于判断: 468.832 <= 150.0 = False
# 检查重量 468.832g 是否在范围 <=400 内
# 小于等于判断: 468.832 <= 400.0 = False
# 检查重量 468.832g 是否在范围 <=900 内
# 小于等于判断: 468.832 <= 900.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 468.832磅 (匹配范围: <=900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 468.832g 是否在范围 <=150 内
# 小于等于判断: 468.832 <= 150.0 = False
# 检查重量 468.832g 是否在范围 <=400 内
# 小于等于判断: 468.832 <= 400.0 = False
# 检查重量 468.832g 是否在范围 <=900 内
# 小于等于判断: 468.832 <= 900.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 468.832磅 (匹配范围: <=900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.13
# 固定费用: $3.13
# 检查重量 29.98g 是否在范围 <=960 内
# 小于等于判断: 29.98 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 29.98磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.72
# 固定费用: $2.72
# 检查重量 29.98g 是否在范围 <=960 内
# 小于等于判断: 29.98 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 29.98磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.77
# 固定费用: $2.77
# 检查重量 29.98g 是否在范围 <=960 内
# 小于等于判断: 29.98 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 29.98磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.72
# 固定费用: $2.72
# 检查重量 29.98g 是否在范围 <=960 内
# 小于等于判断: 29.98 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 29.98磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.77
# 固定费用: $2.77
# 检查重量 179.99g 是否在范围 <=960 内
# 小于等于判断: 179.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 179.99磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 179.99g 是否在范围 <=960 内
# 小于等于判断: 179.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 179.99磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 130.0g 是否在范围 <=960 内
# 小于等于判断: 130.0 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 130.0磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 130.0g 是否在范围 <=960 内
# 小于等于判断: 130.0 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 130.0磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 905.834664g 是否在范围 <=150 内
# 小于等于判断: 905.834664 <= 150.0 = False
# 检查重量 905.834664g 是否在范围 <=400 内
# 小于等于判断: 905.834664 <= 400.0 = False
# 检查重量 905.834664g 是否在范围 <=900 内
# 小于等于判断: 905.834664 <= 900.0 = False
# 检查重量 905.834664g 是否在范围 <=1400 内
# 小于等于判断: 905.834664 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 905.834664磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.54
# 固定费用: $4.54
# 检查重量 905.834664g 是否在范围 <=150 内
# 小于等于判断: 905.834664 <= 150.0 = False
# 检查重量 905.834664g 是否在范围 <=400 内
# 小于等于判断: 905.834664 <= 400.0 = False
# 检查重量 905.834664g 是否在范围 <=900 内
# 小于等于判断: 905.834664 <= 900.0 = False
# 检查重量 905.834664g 是否在范围 <=1400 内
# 小于等于判断: 905.834664 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 905.834664磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.75
# 固定费用: $4.75
# 检查重量 89.99g 是否在范围 <=960 内
# 小于等于判断: 89.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 89.99磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 89.99g 是否在范围 <=960 内
# 小于等于判断: 89.99 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 89.99磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.04
# 固定费用: $3.04
# 检查重量 1075.7471759999999g 是否在范围 <=150 内
# 小于等于判断: 1075.7471759999999 <= 150.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=400 内
# 小于等于判断: 1075.7471759999999 <= 400.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=900 内
# 小于等于判断: 1075.7471759999999 <= 900.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=1400 内
# 小于等于判断: 1075.7471759999999 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 1075.7471759999999磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.29
# 固定费用: $4.29
# 检查重量 1075.7471759999999g 是否在范围 <=150 内
# 小于等于判断: 1075.7471759999999 <= 150.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=400 内
# 小于等于判断: 1075.7471759999999 <= 400.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=900 内
# 小于等于判断: 1075.7471759999999 <= 900.0 = False
# 检查重量 1075.7471759999999g 是否在范围 <=1400 内
# 小于等于判断: 1075.7471759999999 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 1075.7471759999999磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.49
# 固定费用: $4.49
# 检查重量 8937.6g 是否在范围 <=760 内
# 小于等于判断: 8937.6 <= 760.0 = False
# 检查重量 8937.6g 是否在范围 >760 内
# 大于判断: 8937.6 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8937.6磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((8937.6-760)/1000)*0.24
# 计算结果: $6.63
# 检查重量 8937.6g 是否在范围 <=760 内
# 小于等于判断: 8937.6 <= 760.0 = False
# 检查重量 8937.6g 是否在范围 >760 内
# 大于判断: 8937.6 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8937.6磅 (匹配范围: >760g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.67+((发货重量-760)/1000)*0.24
# 计算公式: 4.67+((8937.6-760)/1000)*0.24
# 计算结果: $6.63
# 检查重量 905.834664g 是否在范围 <=150 内
# 小于等于判断: 905.834664 <= 150.0 = False
# 检查重量 905.834664g 是否在范围 <=400 内
# 小于等于判断: 905.834664 <= 400.0 = False
# 检查重量 905.834664g 是否在范围 <=900 内
# 小于等于判断: 905.834664 <= 900.0 = False
# 检查重量 905.834664g 是否在范围 <=1400 内
# 小于等于判断: 905.834664 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 905.834664磅 (匹配范围: <=1400g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.26
# 固定费用: $3.26
# 检查重量 905.834664g 是否在范围 <=150 内
# 小于等于判断: 905.834664 <= 150.0 = False
# 检查重量 905.834664g 是否在范围 <=400 内
# 小于等于判断: 905.834664 <= 400.0 = False
# 检查重量 905.834664g 是否在范围 <=900 内
# 小于等于判断: 905.834664 <= 900.0 = False
# 检查重量 905.834664g 是否在范围 <=1400 内
# 小于等于判断: 905.834664 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 905.834664磅 (匹配范围: <=1400g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.36
# 固定费用: $3.36
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.72
# 固定费用: $2.72
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.77
# 固定费用: $2.77
# 检查重量 5141.850400000001g 是否在范围 <=150 内
# 小于等于判断: 5141.850400000001 <= 150.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=400 内
# 小于等于判断: 5141.850400000001 <= 400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=900 内
# 小于等于判断: 5141.850400000001 <= 900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1400 内
# 小于等于判断: 5141.850400000001 <= 1400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1900 内
# 小于等于判断: 5141.850400000001 <= 1900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=2900 内
# 小于等于判断: 5141.850400000001 <= 2900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=3900 内
# 小于等于判断: 5141.850400000001 <= 3900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=5900 内
# 小于等于判断: 5141.850400000001 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 5141.850400000001磅 (匹配范围: <=5900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.19
# 固定费用: $5.19
# 检查重量 5141.850400000001g 是否在范围 <=150 内
# 小于等于判断: 5141.850400000001 <= 150.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=400 内
# 小于等于判断: 5141.850400000001 <= 400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=900 内
# 小于等于判断: 5141.850400000001 <= 900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1400 内
# 小于等于判断: 5141.850400000001 <= 1400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1900 内
# 小于等于判断: 5141.850400000001 <= 1900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=2900 内
# 小于等于判断: 5141.850400000001 <= 2900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=3900 内
# 小于等于判断: 5141.850400000001 <= 3900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=5900 内
# 小于等于判断: 5141.850400000001 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 5141.850400000001磅 (匹配范围: <=5900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.34
# 固定费用: $5.34
# 检查重量 5251.178200000001g 是否在范围 <=150 内
# 小于等于判断: 5251.178200000001 <= 150.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=400 内
# 小于等于判断: 5251.178200000001 <= 400.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=900 内
# 小于等于判断: 5251.178200000001 <= 900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=1400 内
# 小于等于判断: 5251.178200000001 <= 1400.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=1900 内
# 小于等于判断: 5251.178200000001 <= 1900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=2900 内
# 小于等于判断: 5251.178200000001 <= 2900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=3900 内
# 小于等于判断: 5251.178200000001 <= 3900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=5900 内
# 小于等于判断: 5251.178200000001 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 5251.178200000001磅 (匹配范围: <=5900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.95
# 固定费用: $5.95
# 检查重量 5251.178200000001g 是否在范围 <=150 内
# 小于等于判断: 5251.178200000001 <= 150.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=400 内
# 小于等于判断: 5251.178200000001 <= 400.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=900 内
# 小于等于判断: 5251.178200000001 <= 900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=1400 内
# 小于等于判断: 5251.178200000001 <= 1400.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=1900 内
# 小于等于判断: 5251.178200000001 <= 1900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=2900 内
# 小于等于判断: 5251.178200000001 <= 2900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=3900 内
# 小于等于判断: 5251.178200000001 <= 3900.0 = False
# 检查重量 5251.178200000001g 是否在范围 <=5900 内
# 小于等于判断: 5251.178200000001 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 5251.178200000001磅 (匹配范围: <=5900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 6.23
# 固定费用: $6.23
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.42
# 固定费用: $3.42
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.42
# 固定费用: $3.42
# 检查重量 139.98g 是否在范围 <=210 内
# 小于等于判断: 139.98 <= 210.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准信封
# 使用的重量: 139.98磅 (匹配范围: <=210g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.57
# 固定费用: $2.57
# 检查重量 139.98g 是否在范围 <=210 内
# 小于等于判断: 139.98 <= 210.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准信封
# 使用的重量: 139.98磅 (匹配范围: <=210g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.57
# 固定费用: $2.57
# 检查重量 139.98g 是否在范围 <=210 内
# 小于等于判断: 139.98 <= 210.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准信封
# 使用的重量: 139.98磅 (匹配范围: <=210g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.57
# 固定费用: $2.57
# 检查重量 139.98g 是否在范围 <=210 内
# 小于等于判断: 139.98 <= 210.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准信封
# 使用的重量: 139.98磅 (匹配范围: <=210g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.57
# 固定费用: $2.57
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.42
# 固定费用: $3.42
# 检查重量 210.01g 是否在范围 <=960 内
# 小于等于判断: 210.01 <= 960.0 = True
#
# 计算费用详情:
# 商品尺寸: 超大号信封
# 使用的重量: 210.01磅 (匹配范围: <=960g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.42
# 固定费用: $3.42
# 检查重量 170.01g 是否在范围 <=150 内
# 小于等于判断: 170.01 <= 150.0 = False
# 检查重量 170.01g 是否在范围 <=400 内
# 小于等于判断: 170.01 <= 400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 170.01磅 (匹配范围: <=400g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 3.4
# 固定费用: $3.4
# 检查重量 170.01g 是否在范围 <=150 内
# 小于等于判断: 170.01 <= 150.0 = False
# 检查重量 170.01g 是否在范围 <=400 内
# 小于等于判断: 170.01 <= 400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 170.01磅 (匹配范围: <=400g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 3.56
# 固定费用: $3.56
# 检查重量 20520.02g 是否在范围 <=760 内
# 小于等于判断: 20520.02 <= 760.0 = False
# 检查重量 20520.02g 是否在范围 >760 内
# 大于判断: 20520.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 20520.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((20520.02-760)/1000)*0.36
# 计算结果: $16.89
# 检查重量 20520.02g 是否在范围 <=760 内
# 小于等于判断: 20520.02 <= 760.0 = False
# 检查重量 20520.02g 是否在范围 >760 内
# 大于判断: 20520.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 20520.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((20520.02-760)/1000)*0.36
# 计算结果: $16.89
# 检查重量 41730.0g 是否在范围 <=30000 内
# 小于等于判断: 41730.0 <= 30000.0 = False
# 检查重量 41730.0g 是否在范围 <=40000 内
# 小于等于判断: 41730.0 <= 40000.0 = False
# 检查重量 41730.0g 是否在范围 <=50000 内
# 小于等于判断: 41730.0 <= 50000.0 = True
#
# 计算费用详情:
# 商品尺寸: 特殊大件
# 使用的重量: 41730.0磅 (匹配范围: <=50000g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 47.98
# 固定费用: $47.98
# 检查重量 41730.0g 是否在范围 <=30000 内
# 小于等于判断: 41730.0 <= 30000.0 = False
# 检查重量 41730.0g 是否在范围 <=40000 内
# 小于等于判断: 41730.0 <= 40000.0 = False
# 检查重量 41730.0g 是否在范围 <=50000 内
# 小于等于判断: 41730.0 <= 50000.0 = True
#
# 计算费用详情:
# 商品尺寸: 特殊大件
# 使用的重量: 41730.0磅 (匹配范围: <=50000g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 47.98
# 固定费用: $47.98
# 检查重量 11260.02g 是否在范围 <=760 内
# 小于等于判断: 11260.02 <= 760.0 = False
# 检查重量 11260.02g 是否在范围 >760 内
# 大于判断: 11260.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 11260.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((11260.02-760)/1000)*0.29
# 计算结果: $7.96
# 检查重量 11260.02g 是否在范围 <=760 内
# 小于等于判断: 11260.02 <= 760.0 = False
# 检查重量 11260.02g 是否在范围 >760 内
# 大于判断: 11260.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 11260.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((11260.02-760)/1000)*0.29
# 计算结果: $7.96
# 检查重量 15104.99g 是否在范围 <=760 内
# 小于等于判断: 15104.99 <= 760.0 = False
# 检查重量 15104.99g 是否在范围 >760 内
# 大于判断: 15104.99 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 15104.99磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((15104.99-760)/1000)*0.36
# 计算结果: $14.94
# 检查重量 15104.99g 是否在范围 <=760 内
# 小于等于判断: 15104.99 <= 760.0 = False
# 检查重量 15104.99g 是否在范围 >760 内
# 大于判断: 15104.99 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 15104.99磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((15104.99-760)/1000)*0.36
# 计算结果: $14.94
# 检查重量 8323.01g 是否在范围 <=760 内
# 小于等于判断: 8323.01 <= 760.0 = False
# 检查重量 8323.01g 是否在范围 >760 内
# 大于判断: 8323.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8323.01磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((8323.01-760)/1000)*0.29
# 计算结果: $7.1
# 检查重量 8323.01g 是否在范围 <=760 内
# 小于等于判断: 8323.01 <= 760.0 = False
# 检查重量 8323.01g 是否在范围 >760 内
# 大于判断: 8323.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8323.01磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((8323.01-760)/1000)*0.29
# 计算结果: $7.1
# 检查重量 3769.99g 是否在范围 <=150 内
# 小于等于判断: 3769.99 <= 150.0 = False
# 检查重量 3769.99g 是否在范围 <=400 内
# 小于等于判断: 3769.99 <= 400.0 = False
# 检查重量 3769.99g 是否在范围 <=900 内
# 小于等于判断: 3769.99 <= 900.0 = False
# 检查重量 3769.99g 是否在范围 <=1400 内
# 小于等于判断: 3769.99 <= 1400.0 = False
# 检查重量 3769.99g 是否在范围 <=1900 内
# 小于等于判断: 3769.99 <= 1900.0 = False
# 检查重量 3769.99g 是否在范围 <=2900 内
# 小于等于判断: 3769.99 <= 2900.0 = False
# 检查重量 3769.99g 是否在范围 <=3900 内
# 小于等于判断: 3769.99 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3769.99磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.67
# 固定费用: $5.67
# 检查重量 3769.99g 是否在范围 <=150 内
# 小于等于判断: 3769.99 <= 150.0 = False
# 检查重量 3769.99g 是否在范围 <=400 内
# 小于等于判断: 3769.99 <= 400.0 = False
# 检查重量 3769.99g 是否在范围 <=900 内
# 小于等于判断: 3769.99 <= 900.0 = False
# 检查重量 3769.99g 是否在范围 <=1400 内
# 小于等于判断: 3769.99 <= 1400.0 = False
# 检查重量 3769.99g 是否在范围 <=1900 内
# 小于等于判断: 3769.99 <= 1900.0 = False
# 检查重量 3769.99g 是否在范围 <=2900 内
# 小于等于判断: 3769.99 <= 2900.0 = False
# 检查重量 3769.99g 是否在范围 <=3900 内
# 小于等于判断: 3769.99 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3769.99磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.94
# 固定费用: $5.94
# 检查重量 3130.01g 是否在范围 <=760 内
# 小于等于判断: 3130.01 <= 760.0 = False
# 检查重量 3130.01g 是否在范围 >760 内
# 大于判断: 3130.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 3130.01磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((3130.01-760)/1000)*0.29
# 计算结果: $5.6
# 检查重量 3130.01g 是否在范围 <=760 内
# 小于等于判断: 3130.01 <= 760.0 = False
# 检查重量 3130.01g 是否在范围 >760 内
# 大于判断: 3130.01 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 3130.01磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((3130.01-760)/1000)*0.29
# 计算结果: $5.6
# 检查重量 2010.0g 是否在范围 <=150 内
# 小于等于判断: 2010.0 <= 150.0 = False
# 检查重量 2010.0g 是否在范围 <=400 内
# 小于等于判断: 2010.0 <= 400.0 = False
# 检查重量 2010.0g 是否在范围 <=900 内
# 小于等于判断: 2010.0 <= 900.0 = False
# 检查重量 2010.0g 是否在范围 <=1400 内
# 小于等于判断: 2010.0 <= 1400.0 = False
# 检查重量 2010.0g 是否在范围 <=1900 内
# 小于等于判断: 2010.0 <= 1900.0 = False
# 检查重量 2010.0g 是否在范围 <=2900 内
# 小于等于判断: 2010.0 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2010.0磅 (匹配范围: <=2900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.2
# 固定费用: $5.2
# 检查重量 2010.0g 是否在范围 <=150 内
# 小于等于判断: 2010.0 <= 150.0 = False
# 检查重量 2010.0g 是否在范围 <=400 内
# 小于等于判断: 2010.0 <= 400.0 = False
# 检查重量 2010.0g 是否在范围 <=900 内
# 小于等于判断: 2010.0 <= 900.0 = False
# 检查重量 2010.0g 是否在范围 <=1400 内
# 小于等于判断: 2010.0 <= 1400.0 = False
# 检查重量 2010.0g 是否在范围 <=1900 内
# 小于等于判断: 2010.0 <= 1900.0 = False
# 检查重量 2010.0g 是否在范围 <=2900 内
# 小于等于判断: 2010.0 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2010.0磅 (匹配范围: <=2900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.44
# 固定费用: $5.44
# 检查重量 3099.99g 是否在范围 <=760 内
# 小于等于判断: 3099.99 <= 760.0 = False
# 检查重量 3099.99g 是否在范围 >760 内
# 大于判断: 3099.99 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 3099.99磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((3099.99-760)/1000)*0.29
# 计算结果: $5.59
# 检查重量 3099.99g 是否在范围 <=760 内
# 小于等于判断: 3099.99 <= 760.0 = False
# 检查重量 3099.99g 是否在范围 >760 内
# 大于判断: 3099.99 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 3099.99磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((3099.99-760)/1000)*0.29
# 计算结果: $5.59
# 检查重量 12120.300000000001g 是否在范围 <=760 内
# 小于等于判断: 12120.300000000001 <= 760.0 = False
# 检查重量 12120.300000000001g 是否在范围 >760 内
# 大于判断: 12120.300000000001 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 12120.300000000001磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((12120.300000000001-760)/1000)*0.36
# 计算结果: $13.87
# 检查重量 12120.300000000001g 是否在范围 <=760 内
# 小于等于判断: 12120.300000000001 <= 760.0 = False
# 检查重量 12120.300000000001g 是否在范围 >760 内
# 大于判断: 12120.300000000001 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 12120.300000000001磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((12120.300000000001-760)/1000)*0.36
# 计算结果: $13.87
# 检查重量 9795.38g 是否在范围 <=760 内
# 小于等于判断: 9795.38 <= 760.0 = False
# 检查重量 9795.38g 是否在范围 >760 内
# 大于判断: 9795.38 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9795.38磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((9795.38-760)/1000)*0.29
# 计算结果: $7.53
# 检查重量 9795.38g 是否在范围 <=760 内
# 小于等于判断: 9795.38 <= 760.0 = False
# 检查重量 9795.38g 是否在范围 >760 内
# 大于判断: 9795.38 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9795.38磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((9795.38-760)/1000)*0.29
# 计算结果: $7.53
# 检查重量 5190.0g 是否在范围 <=760 内
# 小于等于判断: 5190.0 <= 760.0 = False
# 检查重量 5190.0g 是否在范围 >760 内
# 大于判断: 5190.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 5190.0磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((5190.0-760)/1000)*0.29
# 计算结果: $6.19
# 检查重量 5190.0g 是否在范围 <=760 内
# 小于等于判断: 5190.0 <= 760.0 = False
# 检查重量 5190.0g 是否在范围 >760 内
# 大于判断: 5190.0 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 5190.0磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((5190.0-760)/1000)*0.29
# 计算结果: $6.19
# 检查重量 936.2344000000002g 是否在范围 <=150 内
# 小于等于判断: 936.2344000000002 <= 150.0 = False
# 检查重量 936.2344000000002g 是否在范围 <=400 内
# 小于等于判断: 936.2344000000002 <= 400.0 = False
# 检查重量 936.2344000000002g 是否在范围 <=900 内
# 小于等于判断: 936.2344000000002 <= 900.0 = False
# 检查重量 936.2344000000002g 是否在范围 <=1400 内
# 小于等于判断: 936.2344000000002 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 936.2344000000002磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.29
# 固定费用: $4.29
# 检查重量 936.2344000000002g 是否在范围 <=150 内
# 小于等于判断: 936.2344000000002 <= 150.0 = False
# 检查重量 936.2344000000002g 是否在范围 <=400 内
# 小于等于判断: 936.2344000000002 <= 400.0 = False
# 检查重量 936.2344000000002g 是否在范围 <=900 内
# 小于等于判断: 936.2344000000002 <= 900.0 = False
# 检查重量 936.2344000000002g 是否在范围 <=1400 内
# 小于等于判断: 936.2344000000002 <= 1400.0 = True
#
# 计算费用详情:
# 商品尺寸: 小包裹
# 使用的重量: 936.2344000000002磅 (匹配范围: <=1400g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.49
# 固定费用: $4.49
# 检查重量 2760.02g 是否在范围 <=760 内
# 小于等于判断: 2760.02 <= 760.0 = False
# 检查重量 2760.02g 是否在范围 >760 内
# 大于判断: 2760.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 2760.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((2760.02-760)/1000)*0.29
# 计算结果: $5.49
# 检查重量 2760.02g 是否在范围 <=760 内
# 小于等于判断: 2760.02 <= 760.0 = False
# 检查重量 2760.02g 是否在范围 >760 内
# 大于判断: 2760.02 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 2760.02磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((2760.02-760)/1000)*0.29
# 计算结果: $5.49
# 检查重量 9549.678600000001g 是否在范围 <=760 内
# 小于等于判断: 9549.678600000001 <= 760.0 = False
# 检查重量 9549.678600000001g 是否在范围 >760 内
# 大于判断: 9549.678600000001 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9549.678600000001磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((9549.678600000001-760)/1000)*0.29
# 计算结果: $7.46
# 检查重量 9549.678600000001g 是否在范围 <=760 内
# 小于等于判断: 9549.678600000001 <= 760.0 = False
# 检查重量 9549.678600000001g 是否在范围 >760 内
# 大于判断: 9549.678600000001 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9549.678600000001磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((9549.678600000001-760)/1000)*0.29
# 计算结果: $7.46
# 检查重量 8937.6g 是否在范围 <=760 内
# 小于等于判断: 8937.6 <= 760.0 = False
# 检查重量 8937.6g 是否在范围 >760 内
# 大于判断: 8937.6 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8937.6磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((8937.6-760)/1000)*0.29
# 计算结果: $7.28
# 检查重量 8937.6g 是否在范围 <=760 内
# 小于等于判断: 8937.6 <= 760.0 = False
# 检查重量 8937.6g 是否在范围 >760 内
# 大于判断: 8937.6 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 8937.6磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((8937.6-760)/1000)*0.29
# 计算结果: $7.28
# 检查重量 13490.002785g 是否在范围 <=760 内
# 小于等于判断: 13490.002785 <= 760.0 = False
# 检查重量 13490.002785g 是否在范围 >760 内
# 大于判断: 13490.002785 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 13490.002785磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((13490.002785-760)/1000)*0.29
# 计算结果: $8.6
# 检查重量 13490.002785g 是否在范围 <=760 内
# 小于等于判断: 13490.002785 <= 760.0 = False
# 检查重量 13490.002785g 是否在范围 >760 内
# 大于判断: 13490.002785 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 13490.002785磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((13490.002785-760)/1000)*0.29
# 计算结果: $8.6
# 检查重量 9640.9566g 是否在范围 <=760 内
# 小于等于判断: 9640.9566 <= 760.0 = False
# 检查重量 9640.9566g 是否在范围 >760 内
# 大于判断: 9640.9566 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9640.9566磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((9640.9566-760)/1000)*0.29
# 计算结果: $7.49
# 检查重量 9640.9566g 是否在范围 <=760 内
# 小于等于判断: 9640.9566 <= 760.0 = False
# 检查重量 9640.9566g 是否在范围 >760 内
# 大于判断: 9640.9566 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型标准大件
# 使用的重量: 9640.9566磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.91+((发货重量-760)/1000)*0.29
# 计算公式: 4.91+((9640.9566-760)/1000)*0.29
# 计算结果: $7.49
# 检查重量 5141.850400000001g 是否在范围 <=150 内
# 小于等于判断: 5141.850400000001 <= 150.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=400 内
# 小于等于判断: 5141.850400000001 <= 400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=900 内
# 小于等于判断: 5141.850400000001 <= 900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1400 内
# 小于等于判断: 5141.850400000001 <= 1400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1900 内
# 小于等于判断: 5141.850400000001 <= 1900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=2900 内
# 小于等于判断: 5141.850400000001 <= 2900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=3900 内
# 小于等于判断: 5141.850400000001 <= 3900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=5900 内
# 小于等于判断: 5141.850400000001 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 5141.850400000001磅 (匹配范围: <=5900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.95
# 固定费用: $5.95
# 检查重量 5141.850400000001g 是否在范围 <=150 内
# 小于等于判断: 5141.850400000001 <= 150.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=400 内
# 小于等于判断: 5141.850400000001 <= 400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=900 内
# 小于等于判断: 5141.850400000001 <= 900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1400 内
# 小于等于判断: 5141.850400000001 <= 1400.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=1900 内
# 小于等于判断: 5141.850400000001 <= 1900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=2900 内
# 小于等于判断: 5141.850400000001 <= 2900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=3900 内
# 小于等于判断: 5141.850400000001 <= 3900.0 = False
# 检查重量 5141.850400000001g 是否在范围 <=5900 内
# 小于等于判断: 5141.850400000001 <= 5900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 5141.850400000001磅 (匹配范围: <=5900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 6.23
# 固定费用: $6.23
# 检查重量 3825.3726g 是否在范围 <=150 内
# 小于等于判断: 3825.3726 <= 150.0 = False
# ...
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3019.0775999999996磅 (匹配范围: <=3900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.16
# 固定费用: $5.16
# 检查重量 3019.0775999999996g 是否在范围 <=150 内
# 小于等于判断: 3019.0775999999996 <= 150.0 = False
# 检查重量 3019.0775999999996g 是否在范围 <=400 内
# 小于等于判断: 3019.0775999999996 <= 400.0 = False
# 检查重量 3019.0775999999996g 是否在范围 <=900 内
# 小于等于判断: 3019.0775999999996 <= 900.0 = False
# 检查重量 3019.0775999999996g 是否在范围 <=1400 内
# 小于等于判断: 3019.0775999999996 <= 1400.0 = False
# 检查重量 3019.0775999999996g 是否在范围 <=1900 内
# 小于等于判断: 3019.0775999999996 <= 1900.0 = False
# 检查重量 3019.0775999999996g 是否在范围 <=2900 内
# 小于等于判断: 3019.0775999999996 <= 2900.0 = False
# 检查重量 3019.0775999999996g 是否在范围 <=3900 内
# 小于等于判断: 3019.0775999999996 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3019.0775999999996磅 (匹配范围: <=3900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.32
# 固定费用: $5.32
# 检查重量 2875.7607999999996g 是否在范围 <=150 内
# 小于等于判断: 2875.7607999999996 <= 150.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=400 内
# 小于等于判断: 2875.7607999999996 <= 400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=900 内
# 小于等于判断: 2875.7607999999996 <= 900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1400 内
# 小于等于判断: 2875.7607999999996 <= 1400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1900 内
# 小于等于判断: 2875.7607999999996 <= 1900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=2900 内
# 小于等于判断: 2875.7607999999996 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2875.7607999999996磅 (匹配范围: <=2900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.73
# 固定费用: $4.73
# 检查重量 2875.7607999999996g 是否在范围 <=150 内
# 小于等于判断: 2875.7607999999996 <= 150.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=400 内
# 小于等于判断: 2875.7607999999996 <= 400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=900 内
# 小于等于判断: 2875.7607999999996 <= 900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1400 内
# 小于等于判断: 2875.7607999999996 <= 1400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1900 内
# 小于等于判断: 2875.7607999999996 <= 1900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=2900 内
# 小于等于判断: 2875.7607999999996 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2875.7607999999996磅 (匹配范围: <=2900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.87
# 固定费用: $4.87
# 检查重量 1727.0176g 是否在范围 <=150 内
# 小于等于判断: 1727.0176 <= 150.0 = False
# 检查重量 1727.0176g 是否在范围 <=400 内
# 小于等于判断: 1727.0176 <= 400.0 = False
# 检查重量 1727.0176g 是否在范围 <=900 内
# 小于等于判断: 1727.0176 <= 900.0 = False
# 检查重量 1727.0176g 是否在范围 <=1400 内
# 小于等于判断: 1727.0176 <= 1400.0 = False
# 检查重量 1727.0176g 是否在范围 <=1900 内
# 小于等于判断: 1727.0176 <= 1900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1727.0176磅 (匹配范围: <=1900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.97
# 固定费用: $4.97
# 检查重量 1727.0176g 是否在范围 <=150 内
# 小于等于判断: 1727.0176 <= 150.0 = False
# 检查重量 1727.0176g 是否在范围 <=400 内
# 小于等于判断: 1727.0176 <= 400.0 = False
# 检查重量 1727.0176g 是否在范围 <=900 内
# 小于等于判断: 1727.0176 <= 900.0 = False
# 检查重量 1727.0176g 是否在范围 <=1400 内
# 小于等于判断: 1727.0176 <= 1400.0 = False
# 检查重量 1727.0176g 是否在范围 <=1900 内
# 小于等于判断: 1727.0176 <= 1900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1727.0176磅 (匹配范围: <=1900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.2
# 固定费用: $5.2
# 检查重量 2875.7607999999996g 是否在范围 <=150 内
# 小于等于判断: 2875.7607999999996 <= 150.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=400 内
# 小于等于判断: 2875.7607999999996 <= 400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=900 内
# 小于等于判断: 2875.7607999999996 <= 900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1400 内
# 小于等于判断: 2875.7607999999996 <= 1400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1900 内
# 小于等于判断: 2875.7607999999996 <= 1900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=2900 内
# 小于等于判断: 2875.7607999999996 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2875.7607999999996磅 (匹配范围: <=2900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.2
# 固定费用: $5.2
# 检查重量 2875.7607999999996g 是否在范围 <=150 内
# 小于等于判断: 2875.7607999999996 <= 150.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=400 内
# 小于等于判断: 2875.7607999999996 <= 400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=900 内
# 小于等于判断: 2875.7607999999996 <= 900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1400 内
# 小于等于判断: 2875.7607999999996 <= 1400.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=1900 内
# 小于等于判断: 2875.7607999999996 <= 1900.0 = False
# 检查重量 2875.7607999999996g 是否在范围 <=2900 内
# 小于等于判断: 2875.7607999999996 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2875.7607999999996磅 (匹配范围: <=2900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.44
# 固定费用: $5.44
# 检查重量 1710.4559999999997g 是否在范围 <=150 内
# 小于等于判断: 1710.4559999999997 <= 150.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=400 内
# 小于等于判断: 1710.4559999999997 <= 400.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=900 内
# 小于等于判断: 1710.4559999999997 <= 900.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=1400 内
# 小于等于判断: 1710.4559999999997 <= 1400.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=1900 内
# 小于等于判断: 1710.4559999999997 <= 1900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1710.4559999999997磅 (匹配范围: <=1900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.97
# 固定费用: $4.97
# 检查重量 1710.4559999999997g 是否在范围 <=150 内
# 小于等于判断: 1710.4559999999997 <= 150.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=400 内
# 小于等于判断: 1710.4559999999997 <= 400.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=900 内
# 小于等于判断: 1710.4559999999997 <= 900.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=1400 内
# 小于等于判断: 1710.4559999999997 <= 1400.0 = False
# 检查重量 1710.4559999999997g 是否在范围 <=1900 内
# 小于等于判断: 1710.4559999999997 <= 1900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1710.4559999999997磅 (匹配范围: <=1900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.2
# 固定费用: $5.2
# 检查重量 3632.7966399999996g 是否在范围 <=760 内
# 小于等于判断: 3632.7966399999996 <= 760.0 = False
# 检查重量 3632.7966399999996g 是否在范围 >760 内
# 大于判断: 3632.7966399999996 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 小号大件
# 使用的重量: 3632.7966399999996磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.79+((发货重量-760)/1000)*0.48
# 计算公式: 4.79+((3632.7966399999996-760)/1000)*0.48
# 计算结果: $6.17
# 检查重量 3632.7966399999996g 是否在范围 <=760 内
# 小于等于判断: 3632.7966399999996 <= 760.0 = False
# 检查重量 3632.7966399999996g 是否在范围 >760 内
# 大于判断: 3632.7966399999996 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 小号大件
# 使用的重量: 3632.7966399999996磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.79+((发货重量-760)/1000)*0.48
# 计算公式: 4.79+((3632.7966399999996-760)/1000)*0.48
# 计算结果: $6.17
# 检查重量 2644.0684199999996g 是否在范围 <=150 内
# 小于等于判断: 2644.0684199999996 <= 150.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=400 内
# 小于等于判断: 2644.0684199999996 <= 400.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=900 内
# 小于等于判断: 2644.0684199999996 <= 900.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=1400 内
# 小于等于判断: 2644.0684199999996 <= 1400.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=1900 内
# 小于等于判断: 2644.0684199999996 <= 1900.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=2900 内
# 小于等于判断: 2644.0684199999996 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2644.0684199999996磅 (匹配范围: <=2900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.2
# 固定费用: $5.2
# 检查重量 2644.0684199999996g 是否在范围 <=150 内
# 小于等于判断: 2644.0684199999996 <= 150.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=400 内
# 小于等于判断: 2644.0684199999996 <= 400.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=900 内
# 小于等于判断: 2644.0684199999996 <= 900.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=1400 内
# 小于等于判断: 2644.0684199999996 <= 1400.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=1900 内
# 小于等于判断: 2644.0684199999996 <= 1900.0 = False
# 检查重量 2644.0684199999996g 是否在范围 <=2900 内
# 小于等于判断: 2644.0684199999996 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2644.0684199999996磅 (匹配范围: <=2900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.44
# 固定费用: $5.44
# 检查重量 1444.7453999999998g 是否在范围 <=150 内
# 小于等于判断: 1444.7453999999998 <= 150.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=400 内
# 小于等于判断: 1444.7453999999998 <= 400.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=900 内
# 小于等于判断: 1444.7453999999998 <= 900.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=1400 内
# 小于等于判断: 1444.7453999999998 <= 1400.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=1900 内
# 小于等于判断: 1444.7453999999998 <= 1900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1444.7453999999998磅 (匹配范围: <=1900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.97
# 固定费用: $4.97
# 检查重量 1444.7453999999998g 是否在范围 <=150 内
# 小于等于判断: 1444.7453999999998 <= 150.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=400 内
# 小于等于判断: 1444.7453999999998 <= 400.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=900 内
# 小于等于判断: 1444.7453999999998 <= 900.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=1400 内
# 小于等于判断: 1444.7453999999998 <= 1400.0 = False
# 检查重量 1444.7453999999998g 是否在范围 <=1900 内
# 小于等于判断: 1444.7453999999998 <= 1900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 1444.7453999999998磅 (匹配范围: <=1900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.2
# 固定费用: $5.2
# 检查重量 3081.820456g 是否在范围 <=150 内
# 小于等于判断: 3081.820456 <= 150.0 = False
# 检查重量 3081.820456g 是否在范围 <=400 内
# 小于等于判断: 3081.820456 <= 400.0 = False
# 检查重量 3081.820456g 是否在范围 <=900 内
# 小于等于判断: 3081.820456 <= 900.0 = False
# 检查重量 3081.820456g 是否在范围 <=1400 内
# 小于等于判断: 3081.820456 <= 1400.0 = False
# 检查重量 3081.820456g 是否在范围 <=1900 内
# 小于等于判断: 3081.820456 <= 1900.0 = False
# 检查重量 3081.820456g 是否在范围 <=2900 内
# 小于等于判断: 3081.820456 <= 2900.0 = False
# 检查重量 3081.820456g 是否在范围 <=3900 内
# 小于等于判断: 3081.820456 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3081.820456磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.67
# 固定费用: $5.67
# 检查重量 3081.820456g 是否在范围 <=150 内
# 小于等于判断: 3081.820456 <= 150.0 = False
# 检查重量 3081.820456g 是否在范围 <=400 内
# 小于等于判断: 3081.820456 <= 400.0 = False
# 检查重量 3081.820456g 是否在范围 <=900 内
# 小于等于判断: 3081.820456 <= 900.0 = False
# 检查重量 3081.820456g 是否在范围 <=1400 内
# 小于等于判断: 3081.820456 <= 1400.0 = False
# 检查重量 3081.820456g 是否在范围 <=1900 内
# 小于等于判断: 3081.820456 <= 1900.0 = False
# 检查重量 3081.820456g 是否在范围 <=2900 内
# 小于等于判断: 3081.820456 <= 2900.0 = False
# 检查重量 3081.820456g 是否在范围 <=3900 内
# 小于等于判断: 3081.820456 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3081.820456磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.94
# 固定费用: $5.94
# 检查重量 3555.437839200001g 是否在范围 <=760 内
# 小于等于判断: 3555.437839200001 <= 760.0 = False
# 检查重量 3555.437839200001g 是否在范围 >760 内
# 大于判断: 3555.437839200001 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 小号大件
# 使用的重量: 3555.437839200001磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.79+((发货重量-760)/1000)*0.48
# 计算公式: 4.79+((3555.437839200001-760)/1000)*0.48
# 计算结果: $6.13
# 检查重量 3555.437839200001g 是否在范围 <=760 内
# 小于等于判断: 3555.437839200001 <= 760.0 = False
# 检查重量 3555.437839200001g 是否在范围 >760 内
# 大于判断: 3555.437839200001 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 小号大件
# 使用的重量: 3555.437839200001磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.79+((发货重量-760)/1000)*0.48
# 计算公式: 4.79+((3555.437839200001-760)/1000)*0.48
# 计算结果: $6.13
# 检查重量 69.99g 是否在范围 <=20 内
# 小于等于判断: 69.99 <= 20.0 = False
# 检查重量 69.99g 是否在范围 <=40 内
# 小于等于判断: 69.99 <= 40.0 = False
# 检查重量 69.99g 是否在范围 <=60 内
# 小于等于判断: 69.99 <= 60.0 = False
# 检查重量 69.99g 是否在范围 <=80 内
# 小于等于判断: 69.99 <= 80.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型信封
# 使用的重量: 69.99磅 (匹配范围: <=80g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 2.52
# 固定费用: $2.52
# 检查重量 69.99g 是否在范围 <=20 内
# 小于等于判断: 69.99 <= 20.0 = False
# 检查重量 69.99g 是否在范围 <=40 内
# 小于等于判断: 69.99 <= 40.0 = False
# 检查重量 69.99g 是否在范围 <=60 内
# 小于等于判断: 69.99 <= 60.0 = False
# 检查重量 69.99g 是否在范围 <=80 内
# 小于等于判断: 69.99 <= 80.0 = True
#
# 计算费用详情:
# 商品尺寸: 轻型信封
# 使用的重量: 69.99磅 (匹配范围: <=80g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 2.52
# 固定费用: $2.52
# 检查重量 2700.01g 是否在范围 <=150 内
# 小于等于判断: 2700.01 <= 150.0 = False
# 检查重量 2700.01g 是否在范围 <=400 内
# 小于等于判断: 2700.01 <= 400.0 = False
# 检查重量 2700.01g 是否在范围 <=900 内
# 小于等于判断: 2700.01 <= 900.0 = False
# 检查重量 2700.01g 是否在范围 <=1400 内
# 小于等于判断: 2700.01 <= 1400.0 = False
# 检查重量 2700.01g 是否在范围 <=1900 内
# 小于等于判断: 2700.01 <= 1900.0 = False
# 检查重量 2700.01g 是否在范围 <=2900 内
# 小于等于判断: 2700.01 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2700.01磅 (匹配范围: <=2900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 4.73
# 固定费用: $4.73
# 检查重量 2700.01g 是否在范围 <=150 内
# 小于等于判断: 2700.01 <= 150.0 = False
# 检查重量 2700.01g 是否在范围 <=400 内
# 小于等于判断: 2700.01 <= 400.0 = False
# 检查重量 2700.01g 是否在范围 <=900 内
# 小于等于判断: 2700.01 <= 900.0 = False
# 检查重量 2700.01g 是否在范围 <=1400 内
# 小于等于判断: 2700.01 <= 1400.0 = False
# 检查重量 2700.01g 是否在范围 <=1900 内
# 小于等于判断: 2700.01 <= 1900.0 = False
# 检查重量 2700.01g 是否在范围 <=2900 内
# 小于等于判断: 2700.01 <= 2900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 2700.01磅 (匹配范围: <=2900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 4.87
# 固定费用: $4.87
# 检查重量 20996.79g 是否在范围 <=760 内
# 小于等于判断: 20996.79 <= 760.0 = False
# 检查重量 20996.79g 是否在范围 >760 内
# 大于判断: 20996.79 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 20996.79磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((20996.79-760)/1000)*0.36
# 计算结果: $17.07
# 检查重量 20996.79g 是否在范围 <=760 内
# 小于等于判断: 20996.79 <= 760.0 = False
# 检查重量 20996.79g 是否在范围 >760 内
# 大于判断: 20996.79 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 20996.79磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((20996.79-760)/1000)*0.36
# 计算结果: $17.07
# 检查重量 20791.9068032g 是否在范围 <=760 内
# 小于等于判断: 20791.9068032 <= 760.0 = False
# 检查重量 20791.9068032g 是否在范围 >760 内
# 大于判断: 20791.9068032 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 20791.9068032磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((20791.9068032-760)/1000)*0.36
# 计算结果: $16.99
# 检查重量 20791.9068032g 是否在范围 <=760 内
# 小于等于判断: 20791.9068032 <= 760.0 = False
# 检查重量 20791.9068032g 是否在范围 >760 内
# 大于判断: 20791.9068032 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 20791.9068032磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((20791.9068032-760)/1000)*0.36
# 计算结果: $16.99
# 检查重量 8919.98g 是否在范围 <=760 内
# 小于等于判断: 8919.98 <= 760.0 = False
# 检查重量 8919.98g 是否在范围 >760 内
# 大于判断: 8919.98 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 8919.98磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((8919.98-760)/1000)*0.36
# 计算结果: $12.72
# 检查重量 8919.98g 是否在范围 <=760 内
# 小于等于判断: 8919.98 <= 760.0 = False
# 检查重量 8919.98g 是否在范围 >760 内
# 大于判断: 8919.98 > 760.0 = True
#
# 计算费用详情:
# 商品尺寸: 特大号大件
# 使用的重量: 8919.98磅 (匹配范围: >760g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 9.78+((发货重量-760)/1000)*0.36
# 计算公式: 9.78+((8919.98-760)/1000)*0.36
# 计算结果: $12.72
# 检查重量 3153.1032g 是否在范围 <=150 内
# 小于等于判断: 3153.1032 <= 150.0 = False
# 检查重量 3153.1032g 是否在范围 <=400 内
# 小于等于判断: 3153.1032 <= 400.0 = False
# 检查重量 3153.1032g 是否在范围 <=900 内
# 小于等于判断: 3153.1032 <= 900.0 = False
# 检查重量 3153.1032g 是否在范围 <=1400 内
# 小于等于判断: 3153.1032 <= 1400.0 = False
# 检查重量 3153.1032g 是否在范围 <=1900 内
# 小于等于判断: 3153.1032 <= 1900.0 = False
# 检查重量 3153.1032g 是否在范围 <=2900 内
# 小于等于判断: 3153.1032 <= 2900.0 = False
# 检查重量 3153.1032g 是否在范围 <=3900 内
# 小于等于判断: 3153.1032 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3153.1032磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.67
# 固定费用: $5.67
# 检查重量 3153.1032g 是否在范围 <=150 内
# 小于等于判断: 3153.1032 <= 150.0 = False
# 检查重量 3153.1032g 是否在范围 <=400 内
# 小于等于判断: 3153.1032 <= 400.0 = False
# 检查重量 3153.1032g 是否在范围 <=900 内
# 小于等于判断: 3153.1032 <= 900.0 = False
# 检查重量 3153.1032g 是否在范围 <=1400 内
# 小于等于判断: 3153.1032 <= 1400.0 = False
# 检查重量 3153.1032g 是否在范围 <=1900 内
# 小于等于判断: 3153.1032 <= 1900.0 = False
# 检查重量 3153.1032g 是否在范围 <=2900 内
# 小于等于判断: 3153.1032 <= 2900.0 = False
# 检查重量 3153.1032g 是否在范围 <=3900 内
# 小于等于判断: 3153.1032 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3153.1032磅 (匹配范围: <=3900g)
# 国家: 德国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.94
# 固定费用: $5.94
# 检查重量 3182.01g 是否在范围 <=150 内
# 小于等于判断: 3182.01 <= 150.0 = False
# 检查重量 3182.01g 是否在范围 <=400 内
# 小于等于判断: 3182.01 <= 400.0 = False
# 检查重量 3182.01g 是否在范围 <=900 内
# 小于等于判断: 3182.01 <= 900.0 = False
# 检查重量 3182.01g 是否在范围 <=1400 内
# 小于等于判断: 3182.01 <= 1400.0 = False
# 检查重量 3182.01g 是否在范围 <=1900 内
# 小于等于判断: 3182.01 <= 1900.0 = False
# 检查重量 3182.01g 是否在范围 <=2900 内
# 小于等于判断: 3182.01 <= 2900.0 = False
# 检查重量 3182.01g 是否在范围 <=3900 内
# 小于等于判断: 3182.01 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3182.01磅 (匹配范围: <=3900g)
# 国家: 英国
# 时期: 2025年1月15日至2025年10月14日
# 匹配到的费用规则: 5.16
# 固定费用: $5.16
# 检查重量 3182.01g 是否在范围 <=150 内
# 小于等于判断: 3182.01 <= 150.0 = False
# 检查重量 3182.01g 是否在范围 <=400 内
# 小于等于判断: 3182.01 <= 400.0 = False
# 检查重量 3182.01g 是否在范围 <=900 内
# 小于等于判断: 3182.01 <= 900.0 = False
# 检查重量 3182.01g 是否在范围 <=1400 内
# 小于等于判断: 3182.01 <= 1400.0 = False
# 检查重量 3182.01g 是否在范围 <=1900 内
# 小于等于判断: 3182.01 <= 1900.0 = False
# 检查重量 3182.01g 是否在范围 <=2900 内
# 小于等于判断: 3182.01 <= 2900.0 = False
# 检查重量 3182.01g 是否在范围 <=3900 内
# 小于等于判断: 3182.01 <= 3900.0 = True
#
# 计算费用详情:
# 商品尺寸: 标准包裹
# 使用的重量: 3182.01磅 (匹配范围: <=3900g)
# 国家: 英国
# 时期: 2025年10月15日至2026年1月14日
# 匹配到的费用规则: 5.32
# 固定费用: $5.32
#
# 处理完成！
# 总处理商品数: 146

# %%
result_df_us.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result_df_us.head()
#
# NameError: name 'result_df_us' is not defined

# %%
result_df_eu.head()
# Out:
#              sku       fnsku        asin amazon-store  your-price  \
# 0   306104-8C-EU  X0023T6QNT  B010UCCR3A           DE       34.99
# 1  306104-42C-EU  X0023T6Q1L  B07WFDCYZL           DE       32.99
# 2  306104-62C-EU  X0023T6PV7  B07WD9KQ93           DE       52.99
# 3     GH-0012-EU  X0023T5VWB  B08HS15RXP           DE       23.52
# 4  306104-482-EU  X0023T25DJ  B07FKJNGSZ           DE       24.99
#
#    sales-price  longest-side  median-side  shortest-side  length-and-girth  \
# 0        34.99         32.80        22.20           21.8            120.80
# 1        32.99         45.29        22.91           12.4            115.90
# 2        52.99         36.40        31.90           17.5            135.20
# 3        23.52         71.59        49.70            9.4            189.79
# 4        24.99         34.49        12.09           11.3             81.28
#
#   unit-of-dimension  item-package-weight unit-of-weight  \
# 0       centimeters              1380.01          grams
# 1       centimeters              1550.02          grams
# 2       centimeters              2118.00          grams
# 3       centimeters              5280.00          grams
# 4       centimeters               608.00          grams
#
#   european_size_category  european_shipping_weight_g european_country  \
# 0                   标准包裹                    3174.778               德国
# 1                   小号大件                    2573.233               德国
# 2                   标准包裹                    4064.060               德国
# 3                 轻型标准大件                    6689.083               德国
# 4                    小包裹                     942.384               德国
#
#    fba_fee_2025年1月15日至2025年10月14日  fba_fee_2025年10月15日至2026年1月14日
# 0                            5.67                            5.94
# 1                            5.66                            5.66
# 2                            5.95                            6.23
# 3                            6.63                            6.63
# 4                            4.29                            4.49

# %%
result_df_eu.to_csv('eu_fba_fee_results.csv', index=False)
